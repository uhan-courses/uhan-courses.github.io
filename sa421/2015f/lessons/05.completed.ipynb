# %% [markdown]
# # Lesson 5. Practice with SimPy

# %% [markdown]
# ### SA421 Fall 2015

# %% [markdown]
# #### Problem.

# %% [markdown]
# The Bank of Poisson has two service counters, each with its own queue. Counter A is operated by Ann, who is very competent: service times at counter A are uniformly distributed between 1 and 3 minutes. Counter B is operated by Bob, who is new at the job: service times at counter B are uniformly distributed between 2 and 8 minutes.
#
# We consider the bank at its busiest, from 10:00 to 14:00. During this time period, the interarrival time between customers is exponentially distributed with a mean of 2.5 minutes. As is typical in real life, an arriving customer will always join the shorter queue.
# If the queues are equal in length, assume that an arriving customer joins the queue for counter B.
#
# 1. Simulate the operation of the bank for these 4 hours. Assume that the bank is empty at 10:00.
# 2. What is the time average number of customers in each queue?
# 3. What fraction of time is Ann busy? Bob?
# 4. What fraction of the customers end up waiting in line for Counter A?

# %% [markdown]
# #### Hints.

# %% [markdown]
# * `resource.waitQ` is a list consisting of the processes (entities) waiting to receive a unit of resource `resource`.
#
#
# * As a result, you can determine the current length of the queue of resource `resource` with `len(resource.waitQ)`.

# %% [markdown]
# Here's some Python setup to help you get started.

# %%
##### Setup #####
# Import everything from SimPy
from SimPy.Simulation import *

# Import seed initializer and random sampling functions from NumPy
from numpy.random import seed, uniform, exponential

# Import step plotting and histogram functions from Matplotlib
from matplotlib.pyplot import step, hist

# Run Matplotlib magic to show plots directly in the notebook
# %matplotlib inline

# Make Matplotlib plots display as SVG files, which are cleaner
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %% [markdown]
# Here is the simulation model.
#
# Both resources (`R.Ann` and `R.Bob`) have monitors activated. In addition, there is one custom-made monitor, `M.counterA`, that equals 1 if the customer chooses Counter A, and 0 if the customer chooses Counter B.

# %%
##### Parameters #####
class P:
    # Customers arrive at the entrance with exponentially distributed
    # interarrival times with mean 2.5
    interarrivalTimeMean = 2.5
    
    # Service times for Counter A are uniformly distributed 
    # between 1 and 3
    AServiceTimeMin = 1
    AServiceTimeMax = 3
    
    # Service times for Counter B are uniformly distributed 
    # between 2 and 8
    BServiceTimeMin = 2
    BServiceTimeMax = 8
    
    # Simulation period is 4 continuous hours
    simulationTimeMax =  4 * 60
    

##### Processes #####
# Customer
class Customer(Process):
    def behavior(self):
        # Customer arrives
        print("Time {1}: {0} arrives".format(self.name, now()))
        
        # Customer looks at queue lengths, chooses shorter queue
        # If Ann's queue is shorter, then customer chooses Counter A
        if len(R.Ann.waitQ) < len(R.Bob.waitQ):        #1
            # Customer chooses Counter A
            print("Time {1}: {0} chooses Counter A".format(self.name, now()))
            M.counterA.observe(1)
            yield request, self, R.Ann
            
            # Customer is released from queue and starts service
            print("Time {1}: {0} begins service".format(self.name, now()))
            serviceTime = uniform(low = P.AServiceTimeMin, high = P.AServiceTimeMax)  
            yield hold, self, serviceTime

            # Customer finishes service, leaves
            print("Time {1}: {0} ends service and leaves".format(self.name, now()))
            yield release, self, R.Ann
            
        # Otherwise, the customer chooses Counter B
        else:
            # Customer chooses Counter B
            print("Time {1}: {0} chooses Counter B".format(self.name, now()))
            M.counterA.observe(0)
            yield request, self, R.Bob
            
            # Customer is released from queue and starts service
            print("Time {1}: {0} begins service".format(self.name, now()))
            serviceTime = uniform(low = P.BServiceTimeMin, high = P.BServiceTimeMax)
            yield hold, self, serviceTime

            # Customer finishes service, leaves
            print("Time {1}: {0} ends service and leaves".format(self.name, now()))
            yield release, self, R.Bob        

# Entrance
class Entrance(Process):
    def behavior(self):
        # At the start of the simulation, no customers have arrived
        nCustomers = 0
        
        # Customer arrivals
        while True:
            # Wait until the next arrival
            interarrivalTime = exponential(scale = P.interarrivalTimeMean)
            yield hold, self, interarrivalTime
            
            # Create a new customer using the template defined in the Customer class
            c = Customer(name="Customer {0}".format(nCustomers))
            
            # Activate the customer's behavior
            activate(c, c.behavior())

            # Count this new customer
            nCustomers += 1

            
##### Resources #####
class R:
    Ann = None
    Bob = None
    
    
##### Monitors #####
class M:
    counterA = None

    
##### Experiment #####
def model():
    # Initialize SimPy 
    initialize()

    # Initialize a seed for the random sampling functions
    seed(123)

    # Create resources Ann and Bob
    R.Ann = Resource(capacity = 1, monitored = True)
    R.Bob = Resource(capacity = 1, monitored = True)
    
    # Create monitor for Counter A
    M.counterA = Monitor()

    # Activate the entrance (to generate customers)
    e = Entrance()
    activate(e, e.behavior())
    
    # Run the simulation
    simulate(until = P.simulationTimeMax)

# %% [markdown]
# Next, we run the simulation.

# %%
model()
# Out:
# Time 2.9806803587: Customer 0 arrives
# Time 2.9806803587: Customer 0 chooses Counter B
# Time 2.9806803587: Customer 0 begins service
# Time 3.82334906539: Customer 1 arrives
# Time 3.82334906539: Customer 1 chooses Counter B
# Time 5.82693326993: Customer 2 arrives
# Time 5.82693326993: Customer 2 chooses Counter A
# Time 5.82693326993: Customer 2 begins service
# Time 6.34178908009: Customer 0 ends service and leaves
# Time 6.34178908009: Customer 1 begins service
# Time 7.67314619018: Customer 2 ends service and leaves
# Time 9.00461060865: Customer 3 arrives
# Time 9.00461060865: Customer 3 chooses Counter B
# Time 11.891216293: Customer 4 arrives
# Time 11.891216293: Customer 4 chooses Counter A
# Time 11.891216293: Customer 4 begins service
# Time 13.5305167766: Customer 5 arrives
# Time 13.5305167766: Customer 5 chooses Counter A
# Time 13.6754513294: Customer 4 ends service and leaves
# Time 13.6754513294: Customer 5 begins service
# Time 14.2263742704: Customer 1 ends service and leaves
# Time 14.2263742704: Customer 3 begins service
# Time 14.5813724022: Customer 6 arrives
# Time 14.5813724022: Customer 6 chooses Counter B
# Time 14.7352044003: Customer 7 arrives
# Time 14.7352044003: Customer 7 chooses Counter A
# Time 16.0041327758: Customer 8 arrives
# Time 16.0041327758: Customer 8 chooses Counter B
# Time 16.1335507442: Customer 5 ends service and leaves
# Time 16.1335507442: Customer 7 begins service
# Time 17.4985342051: Customer 7 ends service and leaves
# Time 18.8578077385: Customer 3 ends service and leaves
# Time 18.8578077385: Customer 6 begins service
# Time 19.3526158758: Customer 9 arrives
# Time 19.3526158758: Customer 9 chooses Counter A
# Time 19.3526158758: Customer 9 begins service
# Time 21.2484379741: Customer 10 arrives
# Time 21.2484379741: Customer 10 chooses Counter A
# Time 21.41627105: Customer 9 ends service and leaves
# Time 21.41627105: Customer 10 begins service
# Time 21.9105182754: Customer 6 ends service and leaves
# Time 21.9105182754: Customer 8 begins service
# Time 23.7639831273: Customer 11 arrives
# Time 23.7639831273: Customer 11 chooses Counter B
# Time 24.1151346382: Customer 10 ends service and leaves
# Time 26.1245740672: Customer 12 arrives
# Time 26.1245740672: Customer 12 chooses Counter A
# Time 26.1245740672: Customer 12 begins service
# Time 27.7704918949: Customer 12 ends service and leaves
# Time 28.2572502245: Customer 8 ends service and leaves
# Time 28.2572502245: Customer 11 begins service
# Time 29.3288999168: Customer 13 arrives
# Time 29.3288999168: Customer 13 chooses Counter B
# Time 29.9766793161: Customer 14 arrives
# Time 29.9766793161: Customer 14 chooses Counter A
# Time 29.9766793161: Customer 14 begins service
# Time 30.8460170412: Customer 15 arrives
# Time 30.8460170412: Customer 15 chooses Counter A
# Time 31.0875832404: Customer 16 arrives
# Time 31.0875832404: Customer 16 chooses Counter B
# Time 32.2386315638: Customer 14 ends service and leaves
# Time 32.2386315638: Customer 15 begins service
# Time 32.4279821583: Customer 11 ends service and leaves
# Time 32.4279821583: Customer 13 begins service
# Time 32.509166682: Customer 17 arrives
# Time 32.509166682: Customer 17 chooses Counter A
# Time 33.8962423442: Customer 18 arrives
# Time 33.8962423442: Customer 18 chooses Counter B
# Time 34.1003570905: Customer 15 ends service and leaves
# Time 34.1003570905: Customer 17 begins service
# Time 34.8321078384: Customer 19 arrives
# Time 34.8321078384: Customer 19 chooses Counter A
# Time 35.9530597044: Customer 17 ends service and leaves
# Time 35.9530597044: Customer 19 begins service
# Time 37.3900927442: Customer 13 ends service and leaves
# Time 37.3900927442: Customer 16 begins service
# Time 38.8413797408: Customer 19 ends service and leaves
# Time 40.4285331212: Customer 20 arrives
# Time 40.4285331212: Customer 20 chooses Counter A
# Time 40.4285331212: Customer 20 begins service
# Time 41.6597699114: Customer 20 ends service and leaves
# Time 42.4011127995: Customer 16 ends service and leaves
# Time 42.4011127995: Customer 18 begins service
# Time 42.8736356592: Customer 21 arrives
# Time 42.8736356592: Customer 21 chooses Counter B
# Time 44.2132516649: Customer 22 arrives
# Time 44.2132516649: Customer 22 chooses Counter A
# Time 44.2132516649: Customer 22 begins service
# Time 45.7141623957: Customer 22 ends service and leaves
# Time 46.3048256904: Customer 18 ends service and leaves
# Time 46.3048256904: Customer 21 begins service
# Time 49.2438148974: Customer 23 arrives
# Time 49.2438148974: Customer 23 chooses Counter B
# Time 51.203031276: Customer 21 ends service and leaves
# Time 51.203031276: Customer 23 begins service
# Time 56.3199419915: Customer 23 ends service and leaves
# Time 59.8381606442: Customer 24 arrives
# Time 59.8381606442: Customer 24 chooses Counter B
# Time 59.8381606442: Customer 24 begins service
# Time 62.2108058438: Customer 25 arrives
# Time 62.2108058438: Customer 25 chooses Counter B
# Time 62.5619326401: Customer 24 ends service and leaves
# Time 62.5619326401: Customer 25 begins service
# Time 66.5874571537: Customer 26 arrives
# Time 66.5874571537: Customer 26 chooses Counter B
# Time 68.1802934106: Customer 25 ends service and leaves
# Time 68.1802934106: Customer 26 begins service
# Time 68.5564754936: Customer 27 arrives
# Time 68.5564754936: Customer 27 chooses Counter B
# Time 69.4629234465: Customer 28 arrives
# Time 69.4629234465: Customer 28 chooses Counter A
# Time 69.4629234465: Customer 28 begins service
# Time 70.8119389245: Customer 29 arrives
# Time 70.8119389245: Customer 29 chooses Counter A
# Time 71.8255249781: Customer 28 ends service and leaves
# Time 71.8255249781: Customer 29 begins service
# Time 72.2368764132: Customer 26 ends service and leaves
# Time 72.2368764132: Customer 27 begins service
# Time 73.8463696531: Customer 29 ends service and leaves
# Time 76.0196963517: Customer 30 arrives
# Time 76.0196963517: Customer 30 chooses Counter B
# Time 78.2240365073: Customer 31 arrives
# Time 78.2240365073: Customer 31 chooses Counter A
# Time 78.2240365073: Customer 31 begins service
# Time 78.252759111: Customer 27 ends service and leaves
# Time 78.252759111: Customer 30 begins service
# Time 80.5734146092: Customer 31 ends service and leaves
# Time 80.6754664032: Customer 32 arrives
# Time 80.6754664032: Customer 32 chooses Counter B
# Time 80.8926175696: Customer 33 arrives
# Time 80.8926175696: Customer 33 chooses Counter A
# Time 80.8926175696: Customer 33 begins service
# Time 82.3799503187: Customer 33 ends service and leaves
# Time 84.4990687795: Customer 34 arrives
# Time 84.4990687795: Customer 34 chooses Counter A
# Time 84.4990687795: Customer 34 begins service
# Time 85.0389392815: Customer 35 arrives
# Time 85.0389392815: Customer 35 chooses Counter A
# Time 85.2904591728: Customer 36 arrives
# Time 85.2904591728: Customer 36 chooses Counter B
# Time 85.3068137367: Customer 30 ends service and leaves
# Time 85.3068137367: Customer 32 begins service
# Time 86.6439826945: Customer 34 ends service and leaves
# Time 86.6439826945: Customer 35 begins service
# Time 89.0908154109: Customer 35 ends service and leaves
# Time 90.7046320836: Customer 37 arrives
# Time 90.7046320836: Customer 37 chooses Counter A
# Time 90.7046320836: Customer 37 begins service
# Time 90.745283829: Customer 38 arrives
# Time 90.745283829: Customer 38 chooses Counter A
# Time 91.070307569: Customer 32 ends service and leaves
# Time 91.070307569: Customer 36 begins service
# Time 92.7795356626: Customer 39 arrives
# Time 92.7795356626: Customer 39 chooses Counter B
# Time 92.8934958425: Customer 37 ends service and leaves
# Time 92.8934958425: Customer 38 begins service
# Time 93.1948802641: Customer 40 arrives
# Time 93.1948802641: Customer 40 chooses Counter A
# Time 94.0240654339: Customer 36 ends service and leaves
# Time 94.0240654339: Customer 39 begins service
# Time 94.1545053776: Customer 41 arrives
# Time 94.1545053776: Customer 41 chooses Counter B
# Time 95.2845549: Customer 38 ends service and leaves
# Time 95.2845549: Customer 40 begins service
# Time 96.1752453793: Customer 42 arrives
# Time 96.1752453793: Customer 42 chooses Counter A
# Time 97.0624560482: Customer 40 ends service and leaves
# Time 97.0624560482: Customer 42 begins service
# Time 99.7457960421: Customer 42 ends service and leaves
# Time 100.175887207: Customer 39 ends service and leaves
# Time 100.175887207: Customer 41 begins service
# Time 102.655333519: Customer 43 arrives
# Time 102.655333519: Customer 43 chooses Counter B
# Time 102.766758814: Customer 44 arrives
# Time 102.766758814: Customer 44 chooses Counter A
# Time 102.766758814: Customer 44 begins service
# Time 103.675533268: Customer 45 arrives
# Time 103.675533268: Customer 45 chooses Counter A
# Time 104.320272607: Customer 41 ends service and leaves
# Time 104.320272607: Customer 43 begins service
# Time 104.563130178: Customer 44 ends service and leaves
# Time 104.563130178: Customer 45 begins service
# Time 106.274959909: Customer 45 ends service and leaves
# Time 106.727134205: Customer 46 arrives
# Time 106.727134205: Customer 46 chooses Counter B
# Time 110.321606697: Customer 47 arrives
# Time 110.321606697: Customer 47 chooses Counter A
# Time 110.321606697: Customer 47 begins service
# Time 112.292423499: Customer 43 ends service and leaves
# Time 112.292423499: Customer 46 begins service
# Time 112.570048879: Customer 48 arrives
# Time 112.570048879: Customer 48 chooses Counter B
# Time 112.705010295: Customer 47 ends service and leaves
# Time 113.842435203: Customer 49 arrives
# Time 113.842435203: Customer 49 chooses Counter A
# Time 113.842435203: Customer 49 begins service
# Time 114.531344357: Customer 50 arrives
# Time 114.531344357: Customer 50 chooses Counter A
# Time 115.199188213: Customer 46 ends service and leaves
# Time 115.199188213: Customer 48 begins service
# Time 115.529347231: Customer 49 ends service and leaves
# Time 115.529347231: Customer 50 begins service
# Time 116.330730209: Customer 51 arrives
# Time 116.330730209: Customer 51 chooses Counter B
# Time 116.681458398: Customer 52 arrives
# Time 116.681458398: Customer 52 chooses Counter A
# Time 116.741164201: Customer 50 ends service and leaves
# Time 116.741164201: Customer 52 begins service
# Time 117.652906867: Customer 53 arrives
# Time 117.652906867: Customer 53 chooses Counter A
# Time 119.064292875: Customer 52 ends service and leaves
# Time 119.064292875: Customer 53 begins service
# Time 121.170807564: Customer 53 ends service and leaves
# Time 121.198935514: Customer 48 ends service and leaves
# Time 121.198935514: Customer 51 begins service
# Time 122.338145038: Customer 54 arrives
# Time 122.338145038: Customer 54 chooses Counter B
# Time 123.552818349: Customer 55 arrives
# Time 123.552818349: Customer 55 chooses Counter A
# Time 123.552818349: Customer 55 begins service
# Time 124.505193153: Customer 56 arrives
# Time 124.505193153: Customer 56 chooses Counter A
# Time 124.974277746: Customer 57 arrives
# Time 124.974277746: Customer 57 chooses Counter B
# Time 125.2613477: Customer 55 ends service and leaves
# Time 125.2613477: Customer 56 begins service
# Time 126.938689392: Customer 56 ends service and leaves
# Time 128.32565044: Customer 51 ends service and leaves
# Time 128.32565044: Customer 54 begins service
# Time 129.391154298: Customer 58 arrives
# Time 129.391154298: Customer 58 chooses Counter A
# Time 129.391154298: Customer 58 begins service
# Time 131.434220416: Customer 58 ends service and leaves
# Time 131.551298338: Customer 59 arrives
# Time 131.551298338: Customer 59 chooses Counter A
# Time 131.551298338: Customer 59 begins service
# Time 131.558027547: Customer 60 arrives
# Time 131.558027547: Customer 60 chooses Counter A
# Time 133.639870891: Customer 54 ends service and leaves
# Time 133.639870891: Customer 57 begins service
# Time 134.527989176: Customer 59 ends service and leaves
# Time 134.527989176: Customer 60 begins service
# Time 136.112968002: Customer 60 ends service and leaves
# Time 136.885686059: Customer 57 ends service and leaves
# Time 137.451728548: Customer 61 arrives
# Time 137.451728548: Customer 61 chooses Counter B
# Time 137.451728548: Customer 61 begins service
# Time 139.286704367: Customer 62 arrives
# Time 139.286704367: Customer 62 chooses Counter B
# Time 144.863196784: Customer 61 ends service and leaves
# Time 144.863196784: Customer 62 begins service
# Time 148.408449169: Customer 62 ends service and leaves
# Time 149.567601732: Customer 63 arrives
# Time 149.567601732: Customer 63 chooses Counter B
# Time 149.567601732: Customer 63 begins service
# Time 151.644943901: Customer 64 arrives
# Time 151.644943901: Customer 64 chooses Counter B
# Time 152.898659225: Customer 65 arrives
# Time 152.898659225: Customer 65 chooses Counter A
# Time 152.898659225: Customer 65 begins service
# Time 154.220797254: Customer 65 ends service and leaves
# Time 156.181947837: Customer 66 arrives
# Time 156.181947837: Customer 66 chooses Counter A
# Time 156.181947837: Customer 66 begins service
# Time 156.409413836: Customer 63 ends service and leaves
# Time 156.409413836: Customer 64 begins service
# Time 158.477044533: Customer 67 arrives
# Time 158.477044533: Customer 67 chooses Counter B
# Time 158.683775753: Customer 68 arrives
# Time 158.683775753: Customer 68 chooses Counter A
# Time 158.913676754: Customer 66 ends service and leaves
# Time 158.913676754: Customer 68 begins service
# Time 160.081834742: Customer 69 arrives
# Time 160.081834742: Customer 69 chooses Counter A
# Time 160.322762473: Customer 68 ends service and leaves
# Time 160.322762473: Customer 69 begins service
# Time 161.579322058: Customer 70 arrives
# Time 161.579322058: Customer 70 chooses Counter A
# Time 161.824254817: Customer 71 arrives
# Time 161.824254817: Customer 71 chooses Counter B
# Time 162.418289618: Customer 69 ends service and leaves
# Time 162.418289618: Customer 70 begins service
# Time 162.704755726: Customer 72 arrives
# Time 162.704755726: Customer 72 chooses Counter A
# Time 164.310543492: Customer 64 ends service and leaves
# Time 164.310543492: Customer 67 begins service
# Time 164.808895342: Customer 73 arrives
# Time 164.808895342: Customer 73 chooses Counter B
# Time 165.273458099: Customer 70 ends service and leaves
# Time 165.273458099: Customer 72 begins service
# Time 167.757182402: Customer 72 ends service and leaves
# Time 168.310142168: Customer 74 arrives
# Time 168.310142168: Customer 74 chooses Counter A
# Time 168.310142168: Customer 74 begins service
# Time 168.434638811: Customer 75 arrives
# Time 168.434638811: Customer 75 chooses Counter A
# Time 169.055015477: Customer 67 ends service and leaves
# Time 169.055015477: Customer 71 begins service
# Time 170.727536959: Customer 74 ends service and leaves
# Time 170.727536959: Customer 75 begins service
# Time 172.050642782: Customer 71 ends service and leaves
# Time 172.050642782: Customer 73 begins service
# Time 173.004297647: Customer 76 arrives
# Time 173.004297647: Customer 76 chooses Counter B
# Time 173.289532835: Customer 75 ends service and leaves
# Time 173.919198711: Customer 77 arrives
# Time 173.919198711: Customer 77 chooses Counter A
# Time 173.919198711: Customer 77 begins service
# Time 175.141983054: Customer 77 ends service and leaves
# Time 175.769862482: Customer 73 ends service and leaves
# Time 175.769862482: Customer 76 begins service
# Time 176.655212575: Customer 78 arrives
# Time 176.655212575: Customer 78 chooses Counter B
# Time 181.759097175: Customer 76 ends service and leaves
# Time 181.759097175: Customer 78 begins service
# Time 182.125159044: Customer 79 arrives
# Time 182.125159044: Customer 79 chooses Counter B
# Time 183.576169446: Customer 80 arrives
# Time 183.576169446: Customer 80 chooses Counter A
# Time 183.576169446: Customer 80 begins service
# Time 185.017756867: Customer 81 arrives
# Time 185.017756867: Customer 81 chooses Counter A
# Time 186.106361636: Customer 80 ends service and leaves
# Time 186.106361636: Customer 81 begins service
# Time 187.102472375: Customer 82 arrives
# Time 187.102472375: Customer 82 chooses Counter A
# Time 187.276169962: Customer 81 ends service and leaves
# Time 187.276169962: Customer 82 begins service
# Time 187.936964785: Customer 78 ends service and leaves
# Time 187.936964785: Customer 79 begins service
# Time 189.2871739: Customer 83 arrives
# Time 189.2871739: Customer 83 chooses Counter B
# Time 189.905857368: Customer 82 ends service and leaves
# Time 191.959363085: Customer 79 ends service and leaves
# Time 191.959363085: Customer 83 begins service
# Time 195.850237763: Customer 84 arrives
# Time 195.850237763: Customer 84 chooses Counter B
# Time 197.983902184: Customer 85 arrives
# Time 197.983902184: Customer 85 chooses Counter A
# Time 197.983902184: Customer 85 begins service
# Time 198.463665087: Customer 83 ends service and leaves
# Time 198.463665087: Customer 84 begins service
# Time 199.142200105: Customer 85 ends service and leaves
# Time 201.466132267: Customer 86 arrives
# Time 201.466132267: Customer 86 chooses Counter B
# Time 205.619999541: Customer 84 ends service and leaves
# Time 205.619999541: Customer 86 begins service
# Time 205.77410657: Customer 87 arrives
# Time 205.77410657: Customer 87 chooses Counter B
# Time 206.118331488: Customer 88 arrives
# Time 206.118331488: Customer 88 chooses Counter A
# Time 206.118331488: Customer 88 begins service
# Time 206.33162739: Customer 89 arrives
# Time 206.33162739: Customer 89 chooses Counter A
# Time 207.395162634: Customer 88 ends service and leaves
# Time 207.395162634: Customer 89 begins service
# Time 207.60610408: Customer 90 arrives
# Time 207.60610408: Customer 90 chooses Counter A
# Time 209.243776356: Customer 89 ends service and leaves
# Time 209.243776356: Customer 90 begins service
# Time 209.671191767: Customer 91 arrives
# Time 209.671191767: Customer 91 chooses Counter A
# Time 210.233427917: Customer 92 arrives
# Time 210.233427917: Customer 92 chooses Counter B
# Time 210.488263455: Customer 90 ends service and leaves
# Time 210.488263455: Customer 91 begins service
# Time 212.424238603: Customer 91 ends service and leaves
# Time 213.079229499: Customer 86 ends service and leaves
# Time 213.079229499: Customer 87 begins service
# Time 214.406986264: Customer 93 arrives
# Time 214.406986264: Customer 93 chooses Counter A
# Time 214.406986264: Customer 93 begins service
# Time 214.425621492: Customer 94 arrives
# Time 214.425621492: Customer 94 chooses Counter A
# Time 216.510171716: Customer 93 ends service and leaves
# Time 216.510171716: Customer 94 begins service
# Time 218.674522634: Customer 94 ends service and leaves
# Time 219.926858756: Customer 87 ends service and leaves
# Time 219.926858756: Customer 92 begins service
# Time 221.143747115: Customer 95 arrives
# Time 221.143747115: Customer 95 chooses Counter B
# Time 223.163433121: Customer 92 ends service and leaves
# Time 223.163433121: Customer 95 begins service
# Time 224.306219287: Customer 96 arrives
# Time 224.306219287: Customer 96 chooses Counter B
# Time 227.065662905: Customer 97 arrives
# Time 227.065662905: Customer 97 chooses Counter A
# Time 227.065662905: Customer 97 begins service
# Time 227.140058246: Customer 98 arrives
# Time 227.140058246: Customer 98 chooses Counter A
# Time 227.221877474: Customer 99 arrives
# Time 227.221877474: Customer 99 chooses Counter B
# Time 227.437348219: Customer 95 ends service and leaves
# Time 227.437348219: Customer 96 begins service
# Time 229.337463623: Customer 97 ends service and leaves
# Time 229.337463623: Customer 98 begins service
# Time 230.580972334: Customer 98 ends service and leaves
# Time 230.635957293: Customer 100 arrives
# Time 230.635957293: Customer 100 chooses Counter A
# Time 230.635957293: Customer 100 begins service
# Time 231.769506179: Customer 100 ends service and leaves
# Time 232.274826232: Customer 96 ends service and leaves
# Time 232.274826232: Customer 99 begins service
# Time 232.591646153: Customer 101 arrives
# Time 232.591646153: Customer 101 chooses Counter B
# Time 238.19501546: Customer 99 ends service and leaves
# Time 238.19501546: Customer 101 begins service

# %% [markdown]
# To compute the time average number of customers in each queue:

# %%
print("Time average number of customers in Counter A queue = {0}".format(R.Ann.waitMon.timeAverage()))
print("Time average number of customers in Counter B queue = {0}".format(R.Bob.waitMon.timeAverage()))
# Out:
# Time average number of customers in Counter A queue = 0.149484747096
# Time average number of customers in Counter B queue = 0.780007337491

# %% [markdown]
# To compute Ann and Bob's utilization:

# %%
print("Counter A utilization = {0}".format(R.Ann.actMon.timeAverage()))
print("Counter B utilization = {0}".format(R.Bob.actMon.timeAverage()))
# Out:
# Counter A utilization = 0.468051258936
# Counter B utilization = 0.965732941402

# %% [markdown]
# To compute the fraction of customers who join the queue for Counter A:

# %%
print("Fraction of customers who join the queue for Counter A = {0}".format(M.counterA.mean()))
# Out:
# Fraction of customers who join the queue for Counter A = 0.558823529412

# %% [markdown]
# Note that the simulation above assumes that when choosing a counter, arriving customers only consider the number of customers waiting in each queue. That is, these arriving customers do **not** consider a customer being served as "in the queue". Depending on your perspective, this might not seem very realistic.
#
# How can you change the above simulation so that arriving customers also consider a customer being served as "in the queue"?
#
# *Hint.* Look for `activeQ` in the SimPy documentation.
