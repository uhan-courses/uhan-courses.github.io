# %% [markdown]
# # Exam 1 &mdash; Problem 4

# %% [markdown]
# ### SA421 Fall 2015

# %% [markdown]
# The sample of 100 observations for this problem:

# %%
y = [149.89587058,  115.8147935 ,  186.61791846,  108.33364022,
         100.20956461,  133.91297972,  124.26339422,  184.91310083,
         181.76068473,  118.15713723,  190.11277435,  154.44082295,
         120.75996194,  181.96542283,  183.03857951,  149.24541167,
         172.39260429,  153.74254221,  157.39396481,  158.10243308,
         164.51380233,  153.38676789,  198.62548425,  150.41738303,
         116.77928245,  196.70845199,  187.21818102,  162.56658311,
         103.63621949,  100.07331212,  146.10264091,  131.07553194,
         134.19932677,  153.70362622,  181.97705845,  166.08893304,
         165.13743822,  107.85754004,  106.91636714,  190.81482526,
         119.03722033,  157.7095997 ,  116.94589439,  166.74104534,
         182.12689094,  160.27835124,  174.46964203,  185.87087385,
         169.00537781,  152.78251607,  116.43300083,  131.32875512,
         160.44319619,  134.89210543,  125.22138205,  138.6944749 ,
         106.97601861,  112.74650596,  151.54917798,  149.51664719,
         112.57514822,  109.06125086,  195.9707193 ,  135.07114258,
         142.3285151 ,  105.43898048,  121.09974748,  114.19628149,
         124.22599504,  153.96086594,  135.85953182,  133.84897569,
         181.05784171,  184.73555149,  174.86201706,  165.8208261 ,
         118.52308322,  101.6767949 ,  194.07463285,  108.43829351,
         191.79319124,  118.93515442,  156.71056279,  181.46922954,
         171.55919694,  175.78591153,  182.82043096,  167.60245634,
         109.99976389,  161.15105768,  167.7931616 ,  190.67599154,
         111.65124701,  174.38810788,  151.12581343,  156.45355588,
         136.62196714,  185.69220291,  153.79495487,  106.61400178,
         111.34229565,  146.93410227,  161.43098776,  137.90992762,
         183.37079934,  185.54463352,  134.22530979,  183.83746296,
         105.51974272,  128.98681611,  174.0602141 ,  176.58326282,
         101.88284926,  154.50264063,  160.64597208,  160.22442442,
         115.82719707,  112.71710639,  111.14798333,  196.75814454,
         102.10259696,  108.46659238,  125.1048946 ,  171.78012683,
         186.01723412,  189.27968118,  107.91368585,  124.57424603,
         167.76791276,  196.32770862,  137.49013769,  150.77159231,
         172.88655268,  175.40520414,  110.04451782,  182.72062368,
         100.76279583,  197.81927668,  184.87391074,  150.45914908,
         145.04522065,  150.82503446,  171.24291642,  106.57828292,
         126.60993973,  157.92298606,  133.15076802,  142.69214433,
         136.02328079,  130.43684955,  158.5676885 ,  119.01335205,
         116.25725745,  197.51140362,  102.89425873,  128.71829686,
         178.46154177,  113.50722915,  168.26955563,  199.00018056,
         129.7210956 ,  179.25696348,  163.96610665,  149.23928579,
         101.90136449,  167.88499535,  168.01619181,  165.42911368,
         195.42900859,  120.17129251,  159.41901555,  128.39976931,
         130.94384572,  171.49394844,  155.43949479,  137.74388281,
         162.71710458,  157.5660866 ,  145.11885488,  116.16828923,
         140.8197489 ,  192.92910441,  152.23847784,  169.85942502,
         157.99965757,  106.96173443,  117.34564891,  199.70896356,
         193.19861563,  101.43749395,  138.40212645,  153.63716357,
         186.67348808,  109.28570078,  123.99108357,  151.83904263,
         119.60638488,  163.34458844,  161.76283027,  164.31071223,
         132.83027517,  100.82135639,  168.0100356 ,  189.57855721,
         127.47083587,  178.25276901,  125.90319767,  174.92675296,
         107.70992374,  170.58189183,  156.92395052,  187.41759333,
         143.38471959,  190.78217649,  174.02739944,  190.84654011,
         185.62571303,  170.64555211,  185.52351932,  145.89998342,
         195.7530275 ,  199.60751817,  127.12846308,  123.49079196,
         131.98386667,  133.82737267,  118.80126199,  191.9979183 ,
         115.66748301,  125.69042584,  110.63989184,  160.65586154,
         100.92324299,  188.74288   ,  165.88173893,  124.07921942,
         141.24736671,  199.46361015,  193.03495422,  156.81626099,
         180.04535794,  189.05543308,  164.97821773,  131.27047687,
         187.46097697,  198.32236536,  134.73106845,  142.68031428,
         150.04417626,  110.90056081]

# %% [markdown]
# ##Place any setup code you need here.

# %% [markdown]
# ## Part a.

# %% [markdown]
# *Write your discussion here. Double-click to edit.*

# %% [markdown]
# ## Part b.

# %% [markdown]
# ## Part c.

# %% [markdown]
# *Write your discussion here. Double-click to edit.*
