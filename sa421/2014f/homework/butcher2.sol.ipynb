# %% [markdown]
# # butcher2

# %% [markdown]
# The Markov Butcher Shop sells premium grade A+ beef. Customers arrive at the butcher shop and form a single queue. There is one butcher who serves customers from the queue on a first-come-first-served basis.
#
# Based on historical data, the interarrival time between customers is uniformly distributed between 1.5 and 3.5 minutes. The time for a butcher to fill a single order is uniformly distributed between 2.5 and 6.5 minutes. The interarrival times and service times are assumed to be independent.

# %% [markdown]
# a. Assume there is 1 butcher. Simulate the shop for 2 hours.

# %%
##### Setup #####
# Friendly floating-point division
from __future__ import division

# Import all simulation functions from SimPy
from SimPy.Simulation import *

# Import seed initializor and random sampling functions from NumPy
from numpy.random import seed, uniform


##### Parameters #####
class P:
    # Customers arrive at the entrance with uniformly distributed
    # interarrival times between 1.5 and 3.5 minutes
    interarrivalTimeMin = 1.5
    interarrivalTimeMax = 3.5
    
    # Service times are uniformly distributed between 2.5 and 6.5 minutes
    serviceTimeMin = 2.5
    serviceTimeMax = 6.5
    
    # Number of servers
    nServers = 1
    
    # Shop is open for 2 continuous hours
    simulationTimeMax =  2 * 60
    

##### Processes #####
# Customer
class Customer(Process):
    def behavior(self):
        # Customer arrives, joins queue
        print("Time {1}: {0} arrives and joins queue".format(self.name, now()))
        yield request, self, R.server
        
        # Customer is released from queue and starts service
        print("Time {1}: {0} begins service".format(self.name, now()))
        serviceTime = uniform(low = P.serviceTimeMin, high = P.serviceTimeMax)
        yield hold, self, serviceTime
        
        # Customer finishes service, leaves
        print("Time {1}: {0} ends service and leaves".format(self.name, now()))
        yield release, self, R.server

# Entrance
class Entrance(Process):
    def behavior(self):
        # At the start of the simulation, no customers have arrived
        nCustomers = 0
        
        # Customer arrivals
        while True:
            # Wait until the next arrival
            interarrivalTime = uniform(low = P.interarrivalTimeMin, high = P.interarrivalTimeMax)
            yield hold, self, interarrivalTime
            
            # Create a new customer using the template defined in the Customer class
            c = Customer(name="Customer {0}".format(nCustomers))
            
            # Activate the customer's behavior
            activate(c, c.behavior())

            # Count this new customer
            nCustomers += 1

##### Resources #####
class R:
    # Server
    server = None


##### Experiment #####
def model():
    # Initialize SimPy 
    initialize()

    # Initialize a seed for the random number generator (more on this later in the semester)
    seed(123)

    # Create the server resource
    R.server = Resource(capacity=P.nServers)

    # Activate the entrance (to generate customers)
    e = Entrance()
    activate(e, e.behavior())
    
    # Run the simulation
    simulate(until=P.simulationTimeMax)

model()
# Out:
# Time 2.8929383712: Customer 0 arrives and joins queue
# Time 2.8929383712: Customer 0 begins service
# Time 4.9652170411: Customer 1 arrives and joins queue
# Time 6.30034418545: Customer 0 ends service and leaves
# Time 6.30034418545: Customer 1 begins service
# Time 7.56784657926: Customer 2 arrives and joins queue
# Time 9.91405949951: Customer 3 arrives and joins queue
# Time 11.6782200646: Customer 1 ends service and leaves
# Time 11.6782200646: Customer 2 begins service
# Time 13.3755878963: Customer 4 arrives and joins queue
# Time 15.8374516992: Customer 5 arrives and joins queue
# Time 16.9175390189: Customer 2 ends service and leaves
# Time 16.9175390189: Customer 3 begins service
# Time 18.1216867356: Customer 6 arrives and joins queue
# Time 20.7902510835: Customer 3 ends service and leaves
# Time 20.7902510835: Customer 4 begins service
# Time 21.0797861504: Customer 7 arrives and joins queue
# Time 22.6991419436: Customer 8 arrives and joins queue
# Time 24.9952304543: Customer 9 arrives and joins queue
# Time 25.0445400623: Customer 4 ends service and leaves
# Time 25.0445400623: Customer 5 begins service
# Time 27.9712212657: Customer 10 arrives and joins queue
# Time 28.2745069841: Customer 5 ends service and leaves
# Time 28.2745069841: Customer 6 begins service
# Time 29.822124778: Customer 11 arrives and joins queue
# Time 32.3857799522: Customer 12 arrives and joins queue
# Time 32.9007124794: Customer 6 ends service and leaves
# Time 32.9007124794: Customer 7 begins service
# Time 35.1545818693: Customer 13 arrives and joins queue
# Time 38.1034925191: Customer 14 arrives and joins queue
# Time 38.7984396557: Customer 7 ends service and leaves
# Time 38.7984396557: Customer 8 begins service
# Time 40.8255395404: Customer 15 arrives and joins queue
# Time 42.9714573681: Customer 16 arrives and joins queue
# Time 44.188213186: Customer 8 ends service and leaves
# Time 44.188213186: Customer 9 begins service
# Time 45.1950346794: Customer 17 arrives and joins queue
# Time 47.2824627721: Customer 18 arrives and joins queue
# Time 47.6012661095: Customer 9 ends service and leaves
# Time 47.6012661095: Customer 10 begins service
# Time 50.0444150199: Customer 19 arrives and joins queue
# Time 50.4696858693: Customer 10 ends service and leaves
# Time 50.4696858693: Customer 11 begins service
# Time 52.4118173652: Customer 20 arrives and joins queue
# Time 54.6931369226: Customer 11 ends service and leaves
# Time 54.6931369226: Customer 12 begins service
# Time 54.8991875605: Customer 21 arrives and joins queue
# Time 57.0237100065: Customer 22 arrives and joins queue
# Time 58.8964580838: Customer 12 ends service and leaves
# Time 58.8964580838: Customer 13 begins service
# Time 59.3764126204: Customer 23 arrives and joins queue
# Time 62.7647326568: Customer 24 arrives and joins queue
# Time 64.9700147363: Customer 13 ends service and leaves
# Time 64.9700147363: Customer 14 begins service
# Time 65.2684060086: Customer 25 arrives and joins queue
# Time 66.9996427987: Customer 26 arrives and joins queue
# Time 69.1342137624: Customer 27 arrives and joins queue
# Time 69.9658265435: Customer 14 ends service and leaves
# Time 69.9658265435: Customer 15 begins service
# Time 71.4638661863: Customer 28 arrives and joins queue
# Time 73.4647769171: Customer 29 arrives and joins queue
# Time 75.9308454456: Customer 30 arrives and joins queue
# Time 75.931063175: Customer 15 ends service and leaves
# Time 75.931063175: Customer 16 begins service
# Time 79.4019650168: Customer 31 arrives and joins queue
# Time 80.509003652: Customer 16 ends service and leaves
# Time 80.509003652: Customer 17 begins service
# Time 82.1277540683: Customer 32 arrives and joins queue
# Time 83.491518316: Customer 17 ends service and leaves
# Time 83.491518316: Customer 18 begins service
# Time 85.2804356693: Customer 33 arrives and joins queue
# Time 87.8705716823: Customer 34 arrives and joins queue
# Time 88.4037588296: Customer 18 ends service and leaves
# Time 88.4037588296: Customer 19 begins service
# Time 90.0560993498: Customer 35 arrives and joins queue
# Time 92.1202419858: Customer 19 ends service and leaves
# Time 92.1202419858: Customer 20 begins service
# Time 92.3901437719: Customer 36 arrives and joins queue
# Time 95.6410574555: Customer 37 arrives and joins queue
# Time 97.3454450489: Customer 20 ends service and leaves
# Time 97.3454450489: Customer 21 begins service
# Time 98.1619021304: Customer 38 arrives and joins queue
# Time 100.833775236: Customer 39 arrives and joins queue
# Time 102.522700181: Customer 21 ends service and leaves
# Time 102.522700181: Customer 22 begins service
# Time 103.58358224: Customer 40 arrives and joins queue
# Time 106.768267115: Customer 41 arrives and joins queue
# Time 107.721456385: Customer 22 ends service and leaves
# Time 107.721456385: Customer 23 begins service
# Time 108.434657092: Customer 42 arrives and joins queue
# Time 110.421989841: Customer 43 arrives and joins queue
# Time 112.310435762: Customer 44 arrives and joins queue
# Time 113.27618775: Customer 23 ends service and leaves
# Time 113.27618775: Customer 24 begins service
# Time 114.955349677: Customer 45 arrives and joins queue
# Time 116.159037817: Customer 24 ends service and leaves
# Time 116.159037817: Customer 25 begins service
# Time 118.226003329: Customer 46 arrives and joins queue

# %% [markdown]
# b. How many customers arrive at the shop over the 2 hour period?

# %% [markdown]
# 47 customers arrive (Customers 0 to 46).

# %% [markdown]
# c. Looking ahead: How would you change your model so that there are 2 butchers? 3? $n$? Read the SimPy documentation to find out.

# %% [markdown]
# You should find [this section](http://simpy.sourceforge.net/old/SManual/SManual.html#resources) of the documentation useful.
