# %% [markdown]
# # ks

# %% [markdown]
# #### Problem 1.

# %% [markdown]
# Using a Kolmogorov-Smirnov goodness-of-fit test with $\alpha = 0.05$, determine whether the 250 observations below come from a normal distribution with mean 2.3 and standard deviation 1.8. Based on the result of the test, what can you conclude?
#
# Read the documentation for `norm` in `scipy.stats` carefully to figure out how to specify the mean and standard deviation!

# %%
y = [3.84503888, -1.04459186,  3.07987924,  7.4566586 ,  2.51238639,
        4.1804024 ,  3.53223856,  4.34383202,  5.5259488 ,  3.51887799,
        3.54774476,  3.47189232,  2.03227088, -0.38135398,  1.02386013,
        1.51439203,  4.95068146,  3.68350274,  1.44256664,  4.95211452,
        5.18057796,  1.65493011,  3.19576723,  4.70939925,  0.98519555,
        1.88509745,  1.86259136,  2.29284013,  3.92945503,  2.46787293,
        4.87443081,  0.81349743,  3.49486712,  0.18327452, -2.09575215,
        4.10444478,  1.2979849 ,  4.97833763,  2.76884315,  2.59622744,
        0.7526716 , -0.13423442,  1.73690925,  3.16740679,  1.54824202,
       -1.04305615,  1.41769931, -1.4148654 ,  0.79217874,  0.6235124 ,
        4.25449158,  2.1904221 ,  2.91734042,  0.00833599,  2.81567139,
        4.42233284,  4.02783778, -0.21432963,  5.68820471, -0.67094165,
        1.11050579,  1.69482636,  2.22651891,  1.54219548,  3.7465545 ,
        2.81005185,  1.91902694,  3.01099648,  4.68628358,  3.44229682,
        2.61982472,  3.28299281,  0.99380829,  1.92979087,  0.81124909,
        7.83431832,  2.28336112,  4.80393305,  3.23537123,  2.98972745,
        3.61316365,  3.46449804,  1.68061239,  1.65619365,  2.79897565,
        2.82139636,  3.2428609 ,  1.50074591,  3.03684718,  2.55711493,
        4.52023979,  2.79822   ,  5.40036885,  3.54441893,  0.78744075,
        1.33095109,  0.9796383 ,  1.70844771,  3.78392313,  3.16296361,
        3.59715435,  4.95515242,  4.94945884,  2.64662671, -0.57458964,
        3.97039609,  2.67567567,  4.22861894,  2.48343178,  6.01453583,
        0.63341424,  1.25032635,  2.09981248,  1.17855744,  2.82410092,
        1.04906346,  2.72125591,  0.79583659,  2.34228128,  2.73789775,
        2.00946135,  5.75145423,  3.03628134,  2.56300916,  3.44575157,
        7.61079185,  0.88593017,  1.14603157,  1.98673969,  2.37185932,
        2.88599887,  3.73528406,  3.90533911,  4.93064217, -1.19870025,
        1.58495086,  1.99587529,  2.11458827,  2.85029217,  0.08395227,
        2.37813802, -0.87914889,  5.95585648,  3.42125432,  5.33510377,
        3.67915163,  2.33032186, -1.21275175, -2.09006462,  6.43114693,
        1.08280709,  5.12605124,  1.84826474,  1.57637759,  2.82542714,
       -0.89314026,  1.77321019,  0.0944418 ,  4.20450095,  2.51019536,
        4.76795934,  4.06112838,  1.07041297,  3.85795827,  3.48218054,
        3.67147578,  1.9367184 ,  2.3469931 ,  4.38639574,  3.11912854,
        0.77724508, -1.363292  , -0.61039799,  1.31719355,  2.6137241 ,
        0.99999845,  2.60044443,  4.15088914,  2.18364769,  3.68265772,
        0.96146425, -0.34051382,  1.89446123,  3.28068184,  1.8284181 ,
        1.79738518,  1.7673868 ,  2.7534555 ,  2.84846436,  2.04654239,
        2.00355258,  4.53154214,  2.84229526,  4.69242892,  6.40013127,
        2.0523533 , -0.30288802,  3.41121046,  2.00027012,  4.77746145,
        5.80423442,  1.93916903,  4.48681115,  1.19091988,  3.26686777,
        1.92752441,  5.98191907, -2.8528486 ,  1.46130645,  2.18708771,
        2.98002783,  3.68349867,  4.55496129,  3.90086563,  3.41473253,
        1.49239418,  2.64283089,  2.38637078,  0.82816862, -0.38515893,
        1.50649093,  1.71549627,  0.85994012, -0.37220266,  2.98637502,
        3.36274113,  0.1835891 ,  3.05548387,  5.57946223,  2.2800369 ,
        0.44177335,  4.11066689,  2.70932786,  2.48558223,  1.34652313,
        0.69956412, -0.68766291,  3.28818216,  3.69685696,  4.45747799,
        1.50061545,  0.75277432,  3.53749053,  0.25622355,  5.42754169,
        2.32051363,  0.73089853,  1.5533661 ,  0.98169857, -1.60626765]

# %%
# Import friendly floating-point division
from __future__ import division

# Import sqrt from numpy
from numpy import sqrt

# Import norm, kstwobign from scipy.stats
from scipy.stats import norm, kstwobign

# Mean of proposed distribution
normMean = 2.3

# Standard deviation of proposed distribution
normStd = 1.8

# Get the number of observations
n = len(y)

# Sort the observations
y.sort()

# Compute K-S observed test statistic
d = max([max(norm.cdf(y[i], loc=normMean, scale=normStd) - i/n, (i+1)/n - norm.cdf(y[i], loc=normMean, scale=normStd)) for i in range(n)])

# Print K-S observed test statistic
print("K-S observed test statistic = {0}".format(d))

# Compute p-value
pValue = 1 - kstwobign.cdf(sqrt(n) * d)

# Print p-value
print("K-S p-value = {0}".format(pValue))
# Out:
# K-S observed test statistic = 0.0596797442626
# K-S p-value = 0.335382555456

# %% [markdown]
# Since the $p$-value is higher than our significance level, we do not reject the null hypothesis of the K-S test: we statistically conclude that the observations come from a normal distribution with mean 2.3 and standard deviation 1.8.

# %% [markdown]
# #### Problem 2.

# %% [markdown]
# Using a Kolmogorov-Smirnov goodness-of-fit test with $\alpha = 0.05$, determine whether the 250 observations below come from a Gamma distribution with shape parameter 1.3 and scale parameter 2. Based on the result of the test, what can you conclude?
#
# Read the documentation for `gamma` in `scipy.stats` carefully to figure out how to specify the shape and scale parameters!

# %%
y = [ 0.68064751,  0.82035715,  1.80004496,  1.728553  ,  0.4119213 ,
        3.85994865,  2.64866752,  8.31078209,  4.08509912,  2.31911514,
        0.88695956,  2.33219421,  0.3440202 ,  3.62321279,  1.95205884,
        1.46830536,  1.75607489,  6.50377998,  1.90591536,  2.04884059,
        2.14378322,  5.47410318,  1.93038667,  2.83756272,  0.25138087,
        1.33212312,  2.90375409,  1.71217832,  0.57548828,  1.22411461,
        2.09522118,  1.27302754,  2.12810302,  2.39989784,  3.118244  ,
        3.42473756,  3.85451766,  2.02528537,  1.61173088,  2.84406859,
        2.06711001,  2.32440197,  2.80279249,  4.24892229,  2.82268174,
        0.61907037,  4.43297108,  4.41295133,  1.94099551,  3.83253679,
        1.63245302,  1.94775632,  5.53563889,  1.96915299,  1.34759931,
        0.83450341,  5.83026143,  4.10438666,  2.02612457,  1.80477902,
        3.69023498,  0.17036746,  0.83869296,  3.09441735,  5.23852392,
        4.75546026,  2.93544151,  1.11829694,  1.25991113,  2.20678852,
        4.85004335,  0.41261833,  5.69000213,  7.97011009,  2.55995551,
        3.61668615,  1.42349885,  2.23344548,  1.07763424,  0.7653196 ,
        2.18599889,  2.93060782,  3.32866497,  1.74502234,  3.59005071,
        2.32790018,  1.13605567,  3.69017343,  1.27571385,  2.91364277,
        1.67180778,  4.58442144,  2.44431797,  3.95225624,  1.29071279,
        4.11921754,  1.57386533,  1.10418893,  0.96887725,  1.05094417,
        1.55272104,  7.46007108,  5.78306729,  1.22167219,  1.22855714,
        2.623449  ,  2.00519853,  4.16130975,  1.53448543,  3.56602063,
        1.64100361,  1.50777491,  3.01444548,  0.84471625,  1.51577374,
        4.70844502,  1.73830674,  2.42461412,  2.30763774,  1.05196349,
        1.17700022,  3.65961593,  3.65906394,  3.39442797,  1.23913117,
        5.42783682,  1.15263806,  2.58000651,  0.59975912,  2.68495556,
        4.51798873,  2.59258592,  1.8937482 ,  4.26458015,  0.7360149 ,
        1.30810486,  3.82734609,  4.19442715,  3.40685812,  2.12577442,
        0.70516623,  0.88598757,  1.83955139,  0.38488412,  2.31123116,
        1.40813981,  1.3032128 ,  1.96175858,  3.43382279,  0.97866145,
        3.17588437,  3.84440741,  4.09448701,  0.85703863,  2.86001486,
        1.84167582,  1.30521929,  1.71463185,  3.18178627,  2.36626932,
        3.8496503 ,  2.55913207,  2.60994579,  0.87911134,  4.82012193,
        1.59021119,  3.05458362,  1.15541049,  0.78912998,  2.95289076,
        0.87627749,  3.85643179,  5.30115682,  2.01859362,  1.87068384,
        1.88270254,  1.74092174,  6.79834984,  4.11718314,  8.81533706,
        1.6112634 ,  1.33673997,  0.17605707,  6.11811303,  1.12694579,
        3.89529012,  5.05237872,  1.91744782,  2.45914059,  2.24184549,
        6.86454432,  2.46469522,  3.28754228,  1.73082953,  1.53357085,
        3.95252116,  2.51387387,  2.22140684,  3.51221491,  3.99833313,
        0.62280205,  3.82358353,  1.18923235,  4.33735316,  0.92632147,
        2.00615715,  2.10242559,  5.21683991,  1.39368806,  3.65349243,
        3.68076719,  1.19695822,  7.49806404,  4.44405931,  3.0747746 ,
        0.26118105,  4.95044486,  6.08962016,  3.82349501,  1.88257686,
        5.14201165,  1.53129513,  1.58462562,  1.64312105,  1.00961628,
        3.39247031,  2.46871051,  1.34981609,  2.88812464,  4.61429899,
        2.35187689,  9.75846145,  2.44262422,  0.58493703,  2.04507913,
        2.12885908,  3.88444798,  2.42943537,  3.6001297 ,  3.4394579 ,
        6.07608498,  3.46277359,  0.70514223,  1.74028159,  3.87429125,
        2.61630256,  3.86077089,  2.31717035,  1.03613753,  1.48850033]

# %%
# Import friendly floating-point division
from __future__ import division

# Import sqrt from numpy
from numpy import sqrt

# Import norm, kstwobign from scipy.stats
from scipy.stats import gamma, kstwobign

# Shape of proposed distribution
gammaShape = 1.3

# Scale of proposed distribution
gammaScale = 2

# Get the number of observations
n = len(y)

# Sort the observations
y.sort()

# Compute K-S observed test statistic
d = max([max(gamma.cdf(y[i], gammaShape, scale=gammaScale) - i/n, (i+1)/n - gamma.cdf(y[i], gammaShape, scale=gammaScale)) for i in range(n)])

# Print K-S observed test statistic
print("K-S observed test statistic = {0}".format(d))

# Compute p-value
pValue = 1 - kstwobign.cdf(sqrt(n) * d)

# Print p-value
print("K-S p-value = {0}".format(pValue))
# Out:
# K-S observed test statistic = 0.149159799487
# K-S p-value = 2.94983652631e-05

# %% [markdown]
# Since the $p$-value is lower than our significance level, we reject the null hypothesis of the K-S test: we statistically conclude that the observations do not come from a Gamma distribution with shape parameter 1.3 and scale parameter 2.
